# %%
import numpy as np
data = np.load('Datasets/amazon.npz')
labels = data['node_labels']

# See which labels actually have nodes
unique, counts = np.unique(labels, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {np.int64(1): np.int64(17), np.int64(2): np.int64(272), np.int64(3): np.int64(772), np.int64(4): np.int64(16871), np.int64(5): np.int64(6560)}

# %%
import numpy as np
data = np.load('Datasets/amazon-fasttext.npz')
labels = data['node_labels']

# See which labels actually have nodes
unique, counts = np.unique(labels, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {np.int64(0): np.int64(17), np.int64(1): np.int64(272), np.int64(2): np.int64(772), np.int64(3): np.int64(16871), np.int64(4): np.int64(6560)}

# %%
import numpy as np
data = np.load('Datasets/roman-fasttext.npz')
labels = data['node_labels']

# See which labels actually have nodes
unique, counts = np.unique(labels, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {np.int64(0): np.int64(3162), np.int64(1): np.int64(3137), np.int64(2): np.int64(2510), np.int64(3): np.int64(2376), np.int64(4): np.int64(1383), np.int64(5): np.int64(1224), np.int64(6): np.int64(1080), np.int64(7): np.int64(928), np.int64(8): np.int64(923), np.int64(9): np.int64(872), np.int64(10): np.int64(795), np.int64(11): np.int64(446), np.int64(12): np.int64(370), np.int64(13): np.int64(362), np.int64(14): np.int64(329), np.int64(15): np.int64(321), np.int64(16): np.int64(296), np.int64(17): np.int64(2086)}
